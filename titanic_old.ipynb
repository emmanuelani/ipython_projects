# %%
import pandas as pd
#loading data into pandas
df = pd.read_csv('Titanic dataset.csv')
pd.set_option('display.max_columns', 80)
print(df.head(5))
# print(df.hist())-
print('********')
print(df[df.duplicated()])
print('********')
##reading data
#reading columns
print(df.columns)
print(df[['Name', 'Sex', 'Cabin', 'Ticket', 'Fare']])
#reading rows, the'i' in 'iloc' means integer. i.e iloc means index location
print(df.iloc[68,7])
print(df.loc[df['Age'] > 70])

 
##sorting/describing data
print(df.describe())
print(df.sort_values(['Age','Fare'], ascending=[1,0]))

##making changes to column
#creating new column
# df['Total'] = df['Age'] + df['Fare']
print(df.head())

#saving files
# pd.to_csv('Titanic.csv')

print(df.loc[df['Name'] == 'Emma'])

#Creating a series and dataframe using dictionary
new_df = pd.DataFrame({'Name': ['Emma', 'Michael', 'Gray'],
                        'Age': [22, 24, 23],
                        'State': ['Enugu', 'Edo', 'Imo']}, index = [1,2,3]
                        )
print(new_df)
new_df.set_index('Name', inplace=True)
print(new_df)
print(df[df['Age'] == 23])
print(new_df['Age'] == 23)
print(new_df.loc['Michael'])
new_df['Gender'] = ['Male', 'Male', 'Male'] # Creating a new column

# new_df.drop()
# print(new_df)

df.describe(include='all')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Name.1  \
# 0                            Braund, Mr. Owen Harris     Braund
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings
# 2                             Heikkinen, Miss. Laina  Heikkinen
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle
# 4                           Allen, Mr. William Henry      Allen
#
#                                       Surname     Sex   Age  SibSp  Parch  \
# 0                             Mr. Owen Harris    male  22.0      1      0
# 1  Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                 Miss. Laina  female  26.0      0      0
# 3          Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                           Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Unnamed: 14 Unnamed: 15  \
# 0         A/5 21171   7.2500   NaN        S          NaN         NaN
# 1          PC 17599  71.2833   C85        C          NaN         NaN
# 2  STON/O2. 3101282   7.9250   NaN        S          NaN         NaN
# 3            113803  53.1000  C123        S          NaN         NaN
# 4            373450   8.0500   NaN        S          NaN      Monday
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN     Tuesday   Wednesday    Thursday      Friday
# ********
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Name.1, Surname, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20]
# Index: []
# ********
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Name.1', 'Surname', 'Sex',
#        'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
#                                                   Name     Sex Cabin  \
# 0                              Braund, Mr. Owen Harris    male   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                               Heikkinen, Miss. Laina  female   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123
# 4                             Allen, Mr. William Henry    male   NaN
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male   NaN
# 887                       Graham, Miss. Margaret Edith  female   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  C148
# 890                                Dooley, Mr. Patrick    male   NaN
#
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
# [891 rows x 5 columns]
# 17.0
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#            Name.1                    Surname   Sex   Age  SibSp  Parch  \
# 96    Goldschmidt               Mr. George B  male  71.0      0      0
# 116       Connors                Mr. Patrick  male  70.5      0      0
# 493  Artagaveytia                  Mr. Ramon  male  71.0      0      0
# 630     Barkworth  Mr. Algernon Henry Wilson  male  80.0      0      0
# 851      Svensson                  Mr. Johan  male  74.0      0      0
#
#        Ticket     Fare Cabin Embarked  Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 96   PC 17754  34.6542    A5        C          NaN         NaN          NaN
# 116    370369   7.7500   NaN        Q          NaN         NaN          NaN
# 493  PC 17609  49.5042   NaN        C          NaN         NaN          NaN
# 630     27042  30.0000   A23        S          NaN         NaN          NaN
# 851    347060   7.7750   NaN        S          NaN         NaN          NaN
#
#     Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 96          NaN         NaN         NaN         NaN
# 116         NaN         NaN         NaN         NaN
# 493         NaN         NaN         NaN         NaN
# 630         NaN         NaN         NaN         NaN
# 851         NaN         NaN         NaN         NaN
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Unnamed: 14  Unnamed: 16
# count  891.000000  891.000000          0.0          0.0
# mean     0.381594   32.204208          NaN          NaN
# std      0.806057   49.693429          NaN          NaN
# min      0.000000    0.000000          NaN          NaN
# 25%      0.000000    7.910400          NaN          NaN
# 50%      0.000000   14.454200          NaN          NaN
# 75%      0.000000   31.000000          NaN          NaN
# max      6.000000  512.329200          NaN          NaN
#      PassengerId  Survived  Pclass                              Name  \
# 803          804         1       3   Thomas, Master. Assad Alexander
# 755          756         1       2         Hamalainen, Master. Viljo
# 469          470         1       3     Baclini, Miss. Helene Barbara
# 644          645         1       3            Baclini, Miss. Eugenie
# 78            79         1       2     Caldwell, Master. Alden Gates
# ..           ...       ...     ...                               ...
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"
# 633          634         0       1     Parr, Mr. William Henry Marsh
# 674          675         0       2        Watson, Mr. Ennis Hastings
# 732          733         0       2              Knight, Mr. Robert J
# 815          816         0       1                  Fry, Mr. Richard
#
#          Name.1                    Surname     Sex   Age  SibSp  Parch  \
# 803      Thomas    Master. Assad Alexander    male  0.42      0      1
# 755  Hamalainen              Master. Viljo    male  0.67      1      1
# 469     Baclini       Miss. Helene Barbara  female  0.75      2      1
# 644     Baclini              Miss. Eugenie  female  0.75      2      1
# 78     Caldwell        Master. Alden Gates    male  0.83      0      2
# ..          ...                        ...     ...   ...    ...    ...
# 481       Frost  Mr. Anthony Wood "Archie"    male   NaN      0      0
# 633        Parr    Mr. William Henry Marsh    male   NaN      0      0
# 674      Watson         Mr. Ennis Hastings    male   NaN      0      0
# 732      Knight               Mr. Robert J    male   NaN      0      0
# 815         Fry                Mr. Richard    male   NaN      0      0
#
#      Ticket     Fare Cabin Embarked  Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 803    2625   8.5167   NaN        C          NaN         NaN          NaN
# 755  250649  14.5000   NaN        S          NaN         NaN          NaN
# 469    2666  19.2583   NaN        C          NaN         NaN          NaN
# 644    2666  19.2583   NaN        C          NaN         NaN          NaN
# 78   248738  29.0000   NaN        S          NaN         NaN          NaN
# ..      ...      ...   ...      ...          ...         ...          ...
# 481  239854   0.0000   NaN        S          NaN         NaN          NaN
# 633  112052   0.0000   NaN        S          NaN         NaN          NaN
# 674  239856   0.0000   NaN        S          NaN         NaN          NaN
# 732  239855   0.0000   NaN        S          NaN         NaN          NaN
# 815  112058   0.0000  B102        S          NaN         NaN          NaN
#
#     Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 803         NaN         NaN         NaN         NaN
# 755         NaN         NaN         NaN         NaN
# 469         NaN         NaN         NaN         NaN
# 644         NaN         NaN         NaN         NaN
# 78          NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 481         NaN         NaN         NaN         NaN
# 633         NaN         NaN         NaN         NaN
# 674         NaN         NaN         NaN         NaN
# 732         NaN         NaN         NaN         NaN
# 815         NaN         NaN         NaN         NaN
#
# [891 rows x 21 columns]
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Name.1  \
# 0                            Braund, Mr. Owen Harris     Braund
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings
# 2                             Heikkinen, Miss. Laina  Heikkinen
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle
# 4                           Allen, Mr. William Henry      Allen
#
#                                       Surname     Sex   Age  SibSp  Parch  \
# 0                             Mr. Owen Harris    male  22.0      1      0
# 1  Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                 Miss. Laina  female  26.0      0      0
# 3          Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                           Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Unnamed: 14 Unnamed: 15  \
# 0         A/5 21171   7.2500   NaN        S          NaN         NaN
# 1          PC 17599  71.2833   C85        C          NaN         NaN
# 2  STON/O2. 3101282   7.9250   NaN        S          NaN         NaN
# 3            113803  53.1000  C123        S          NaN         NaN
# 4            373450   8.0500   NaN        S          NaN      Monday
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN     Tuesday   Wednesday    Thursday      Friday
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Name.1, Surname, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20]
# Index: []
#       Name  Age  State
# 1     Emma   22  Enugu
# 2  Michael   24    Edo
# 3     Gray   23    Imo
#          Age  State
# Name
# Emma      22  Enugu
# Michael   24    Edo
# Gray      23    Imo
#      PassengerId  Survived  Pclass  \
# 88            89         1       1
# 97            98         1       1
# 135          136         0       2
# 350          351         0       3
# 393          394         1       1
# 398          399         0       2
# 473          474         1       2
# 529          530         0       2
# 649          650         1       3
# 658          659         0       2
# 733          734         0       2
# 734          735         0       2
# 753          754         0       3
# 816          817         0       3
# 833          834         0       3
#
#                                              Name       Name.1  \
# 88                     Fortune, Miss. Mabel Helen      Fortune
# 97                Greenfield, Mr. William Bertram   Greenfield
# 135                            Richard, Mr. Emile      Richard
# 350                        Odahl, Mr. Nils Martin        Odahl
# 393                        Newell, Miss. Marjorie       Newell
# 398                              Pain, Dr. Alfred         Pain
# 473  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)       Jerwan
# 529                   Hocking, Mr. Richard George      Hocking
# 649               Stanley, Miss. Amy Zillah Elsie      Stanley
# 658                  Eitemiller, Mr. George Floyd   Eitemiller
# 733                    Berriman, Mr. William John     Berriman
# 734                  Troupiansky, Mr. Moses Aaron  Troupiansky
# 753                            Jonkoff, Mr. Lalio      Jonkoff
# 816                  Heininen, Miss. Wendla Maria     Heininen
# 833                        Augustsson, Mr. Albert   Augustsson
#
#                                   Surname     Sex   Age  SibSp  Parch  \
# 88                      Miss. Mabel Helen  female  23.0      3      2
# 97                    Mr. William Bertram    male  23.0      0      1
# 135                             Mr. Emile    male  23.0      0      0
# 350                       Mr. Nils Martin    male  23.0      0      0
# 393                        Miss. Marjorie  female  23.0      1      0
# 398                            Dr. Alfred    male  23.0      0      0
# 473  Mrs. Amin S (Marie Marthe Thuillard)  female  23.0      0      0
# 529                    Mr. Richard George    male  23.0      2      1
# 649                Miss. Amy Zillah Elsie  female  23.0      0      0
# 658                      Mr. George Floyd    male  23.0      0      0
# 733                      Mr. William John    male  23.0      0      0
# 734                       Mr. Moses Aaron    male  23.0      0      0
# 753                             Mr. Lalio    male  23.0      0      0
# 816                    Miss. Wendla Maria  female  23.0      0      0
# 833                            Mr. Albert    male  23.0      0      0
#
#                Ticket      Fare        Cabin Embarked  Unnamed: 14  \
# 88              19950  263.0000  C23 C25 C27        S          NaN
# 97           PC 17759   63.3583      D10 D12        C          NaN
# 135     SC/PARIS 2133   15.0458          NaN        C          NaN
# 350              7267    9.2250          NaN        S          NaN
# 393             35273  113.2750          D36        C          NaN
# 398            244278   10.5000          NaN        S          NaN
# 473   SC/AH Basle 541   13.7917            D        C          NaN
# 529             29104   11.5000          NaN        S          NaN
# 649          CA. 2314    7.5500          NaN        S          NaN
# 658             29751   13.0000          NaN        S          NaN
# 733             28425   13.0000          NaN        S          NaN
# 734            233639   13.0000          NaN        S          NaN
# 753            349204    7.8958          NaN        S          NaN
# 816  STON/O2. 3101290    7.9250          NaN        S          NaN
# 833            347468    7.8542          NaN        S          NaN
#
#     Unnamed: 15  Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 88          NaN          NaN         NaN         NaN         NaN         NaN
# 97          NaN          NaN         NaN         NaN         NaN         NaN
# 135         NaN          NaN         NaN         NaN         NaN         NaN
# 350         NaN          NaN         NaN         NaN         NaN         NaN
# 393         NaN          NaN         NaN         NaN         NaN         NaN
# 398         NaN          NaN         NaN         NaN         NaN         NaN
# 473         NaN          NaN         NaN         NaN         NaN         NaN
# 529         NaN          NaN         NaN         NaN         NaN         NaN
# 649         NaN          NaN         NaN         NaN         NaN         NaN
# 658         NaN          NaN         NaN         NaN         NaN         NaN
# 733         NaN          NaN         NaN         NaN         NaN         NaN
# 734         NaN          NaN         NaN         NaN         NaN         NaN
# 753         NaN          NaN         NaN         NaN         NaN         NaN
# 816         NaN          NaN         NaN         NaN         NaN         NaN
# 833         NaN          NaN         NaN         NaN         NaN         NaN
# Name
# Emma       False
# Michael    False
# Gray        True
# Name: Age, dtype: bool
# Age       24
# State    Edo
# Name: Michael, dtype: object
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                                      Name     Name.1  \
# count                                                 891        891
# unique                                                890        667
# top     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Andersson
# freq                                                    2          9
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#          Surname   Sex         Age       SibSp       Parch  Ticket  \
# count        891   891  714.000000  891.000000  891.000000     891
# unique       803     2         NaN         NaN         NaN     681
# top     Mr. John  male         NaN         NaN         NaN  347082
# freq           7   577         NaN         NaN         NaN       7
# mean         NaN   NaN   29.699118    0.523008    0.381594     NaN
# std          NaN   NaN   14.526497    1.102743    0.806057     NaN
# min          NaN   NaN    0.420000    0.000000    0.000000     NaN
# 25%          NaN   NaN   20.125000    0.000000    0.000000     NaN
# 50%          NaN   NaN   28.000000    0.000000    0.000000     NaN
# 75%          NaN   NaN   38.000000    1.000000    0.000000     NaN
# max          NaN   NaN   80.000000    8.000000    6.000000     NaN
#
#               Fare    Cabin Embarked  Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# count   891.000000      204      889          0.0           1          0.0
# unique         NaN      147        3          NaN           1          NaN
# top            NaN  B96 B98        S          NaN      Monday          NaN
# freq           NaN        4      644          NaN           1          NaN
# mean     32.204208      NaN      NaN          NaN         NaN          NaN
# std      49.693429      NaN      NaN          NaN         NaN          NaN
# min       0.000000      NaN      NaN          NaN         NaN          NaN
# 25%       7.910400      NaN      NaN          NaN         NaN          NaN
# 50%      14.454200      NaN      NaN          NaN         NaN          NaN
# 75%      31.000000      NaN      NaN          NaN         NaN          NaN
# max     512.329200      NaN      NaN          NaN         NaN          NaN
#
#        Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# count            1           1           1           1
# unique           1           1           1           1
# top        Tuesday   Wednesday    Thursday      Friday
# freq             1           1           1           1
# mean           NaN         NaN         NaN         NaN
# std            NaN         NaN         NaN         NaN
# min            NaN         NaN         NaN         NaN
# 25%            NaN         NaN         NaN         NaN
# 50%            NaN         NaN         NaN         NaN
# 75%            NaN         NaN         NaN         NaN
# max            NaN         NaN         NaN         NaN

# %%
# print(df.head())
print(df.shape)
print(df.columns)
df.dropna(axis=1) # Dropping columns with null values
# print(df.sort_values(['Age', 'Fare'], ascending = [True, False]))
'Emmanuel'
pd.isnull(df.head(10))
# df.set_index('PassengerId')
df.sample(5) # returns a specified number of random rows from the dataframe
# df.drop(['Unnamed: 0.1.1.1.1.1 '])
# Out:
# (891, 21)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Name.1', 'Surname', 'Sex',
#        'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
#      PassengerId  Survived  Pclass  \
# 780          781         1       3
# 187          188         1       1
# 523          524         1       1
# 631          632         0       3
# 651          652         1       2
#
#                                                 Name   Name.1  \
# 780                             Ayoub, Miss. Banoura    Ayoub
# 187    Romaine, Mr. Charles Hallace ("Mr C Rolmane")  Romaine
# 523  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  Hippach
# 631                      Lundahl, Mr. Johan Svensson  Lundahl
# 651                              Doling, Miss. Elsie   Doling
#
#                                     Surname     Sex   Age  SibSp  Parch  \
# 780                           Miss. Banoura  female  13.0      0      0
# 187    Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0      0
# 523  Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0      1
# 631                      Mr. Johan Svensson    male  51.0      0      0
# 651                             Miss. Elsie  female  18.0      0      1
#
#      Ticket     Fare Cabin Embarked  Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# 780    2687   7.2292   NaN        C          NaN         NaN          NaN
# 187  111428  26.5500   NaN        S          NaN         NaN          NaN
# 523  111361  57.9792   B18        C          NaN         NaN          NaN
# 631  347743   7.0542   NaN        S          NaN         NaN          NaN
# 651  231919  23.0000   NaN        S          NaN         NaN          NaN
#
#     Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 780         NaN         NaN         NaN         NaN
# 187         NaN         NaN         NaN         NaN
# 523         NaN         NaN         NaN         NaN
# 631         NaN         NaN         NaN         NaN
# 651         NaN         NaN         NaN         NaN

# %%
df['Age'].mean()
df['Age'].isnull().sum() # Geting the total number of null values
df.columns
# df.set_index('PassengerId', inplace = True)
df.isnull().head(10)
df.groupby('Cabin').mean().head()
# df.groupby('Pclass').sum()
df['Cabin'].dropna().head(10).to_frame()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Latitude E7270\Documents\Codes\Personal files\Ipython files\titanic.ipynb Cell 3' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000003?line=3'>4</a> # df.set_index('PassengerId', inplace = True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000003?line=4'>5</a> df.isnull().head(10)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000003?line=5'>6</a> df.groupby('Cabin').mean().head()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000003?line=6'>7</a> # df.groupby('Pclass').sum()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000003?line=7'>8</a> df['Cabin'].dropna().head(10).to_frame()
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
#    7722     dropna=dropna,
#    7723 )
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: 'Cabin'

# %%
import matplotlib.pyplot as plt

# plt.plot(df['Age'],df['Fare'])
plt.show()
Fare_512 = df[df['Fare'] > 200].sort_values(['Fare', 'Age'], ascending = [False, True])
# plt.plot(Fare_512['Age'], Fare_512['Fare'])
Fare_512['Sex'].value_counts()
a = df['Sex'].value_counts(normalize = True)
print(a)
# df.set_index('PassengerId', inplace = True)
df['Cabin'].value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Latitude E7270\Documents\Codes\Personal files\Ipython files\titanic.ipynb Cell 4' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000004?line=8'>9</a> print(a)
#      <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000004?line=9'>10</a> # df.set_index('PassengerId', inplace = True)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000004?line=10'>11</a> df['Cabin'].value_counts(normalize = True)
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Latitude E7270\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Cabin'

# %%
#groupby function
sex_grp = df.groupby(['Sex'])
sex_grp
print(df.columns)
# sex_grp['Pclass'].value_counts(normalize=True)
#aggregate function allows multiple statistical tool in one line of code
print(sex_grp['Age'].agg(['mean', 'median', 'max', 'min']))
sex_grp['Name'].apply(lambda x: x.str.contains('Paulinus').sum())
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Name.1', 'Surname', 'Sex',
#        'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
#              mean  median   max   min
# Sex
# female  27.915709    27.0  63.0  0.75
# male    30.726645    29.0  80.0  0.42
# Sex
# female    0
# male      0
# Name: Name, dtype: int64

# %%
df.columns
df = df.rename(columns={'Name': 'Full_name', 'Cabin': 'Class'})
df.groupby('Sex')['Survived'].value_counts(normalize = True)

# help(pd)
# Out:
# Sex     Survived
# female  1           0.742038
#         0           0.257962
# male    0           0.811092
#         1           0.188908
# Name: Survived, dtype: float64

# %%
# print(df.loc[[678, 23], ['Age', 'Sex','Survived', 'Cabin']])
# print(df.loc[1:11])
# df.reset_index()
# print(df.loc[1:7, 'Name': 'Ticket'])
print(df.columns)

# df.set_index('PassengerId'.upper(), inplace = True)
# df.set_index('Name', inplace=True)
try:
    children = df['AGE'] == 10
except:
    pass
# print(df.loc[children].head(20))
children.value_counts(normalize = True)
df.columns = [c.upper() for c in df.columns] # Changinh the first letter in each column to capital letter
# df.columns = [c for c in df.columns]
# df['AGESA'].lower()
print(df.columns)
# df.loc[[67, 65], ['SEX', 'FULL_NAME', 'AGE']]
df.columns = df.columns.str.replace('_', ' ',)
df
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Full_name', 'Name.1', 'Surname',
#        'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Class', 'Embarked',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Latitude E7270\Documents\Codes\Personal files\Ipython files\titanic.ipynb Cell 7' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000007?line=11'>12</a>     pass
#      <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000007?line=12'>13</a> # print(df.loc[children].head(20))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000007?line=13'>14</a> children.value_counts(normalize = True)
#      <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000007?line=14'>15</a> df.columns = [c.upper() for c in df.columns] # Changinh the first letter in each column to capital letter
#      <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000007?line=15'>16</a> # df.columns = [c for c in df.columns]
#      <a href='vscode-notebook-cell:/c%3A/Users/Latitude%20E7270/Documents/Codes/Personal%20files/Ipython%20files/titanic.ipynb#ch0000007?line=16'>17</a> # df['AGESA'].lower()
#
# NameError: name 'children' is not defined

# %%
df1 = pd.read_csv('TimeUse.csv')
df1.shape
df1.describe

# %%
print(df.columns)
df['Full_name'].apply(len)
df['Sex'] = df['Sex'].map({'male': 'Male', 'female': 'Female'})
df['Survived'] = df['Survived'].replace({0: 'Yes', 1: 'No'})
df['Full_name'] = df['Full_name'].str.split(',', expand = True)
df.append({'Full_name': 'Emmanuel Chisom Ani', 'Sex': 'Male', 'Survived': 'Yes', 'Age': 21}, ignore_index= True)
# print(df)

df[df['Full_name']=='Emmanuel Chisom Ani']
df.drop(df[df['Full_name'] == 'Emmanuel Chisom Ani'].index)
# df.sort_values('Name', ascending = False)
# df
# df.Full_name
# df.apply(pd.Series.mi
pd.isnull(df['Age']. value_counts())
# df[d].value_counts()
df['Age'].nlargest(10)
# df['Age'].sort_values(ascending = False).head(10)
df['Age'].nsmallest(10)
df['Age'].sort_values(ascending = True).head(10)
df['Sex']
df
# Out:
# Failed to start the Kernel.
#
# C:\Users\Latitude E7270\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\traitlets\traitlets.py:2392: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#
#   warn(
#
# C:\Users\Latitude E7270\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\traitlets\traitlets.py:2346: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '1325020e-8963-43a0-8766-6c951739da57' instead of 'b"1325020e-8963-43a0-8766-6c951739da57"'.
#
#   warn(
#
# C:\Users\Latitude E7270\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\traitlets\traitlets.py:2392: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'c:\\Users\\Latitude E7270\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-20900F3MQiz77mMvH.json' instead of '"c:\\Users\\Latitude E7270\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-20900F3MQiz77mMvH.json"' if you require traitlets >=5.
#
#   warn(
#
# Bad file descriptor (C:\projects\libzmq\src\epoll.cpp:100).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(df.columns)
Sex_grp = df.groupby(['Sex'])
# Sex_grp.get_group('Male')
# Sex_grp['Class'].value_counts().loc('male')

df['Survived'].replace([1, 0], ['Yes', 'No'], inplace = True)
# Sex_grp['Survived'].value_counts(normalize = True )
Sex_grp['Age'].agg(['median', 'mean','min', 'max'])
n = df['Full_name'].str.contains('Ani')
df[-n]
# df.isnull().value_counts()
# df.dropna(inplace = True)
# df.dropna(axis=1, inplace = True)
df.isnull().value_counts()
df.fillna(0)
df['Sex'] = df['Sex'].astype(float)
df['Survived'] = df['Survived'].astype(str)
df.dtypes
df
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Full_name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Class', 'Embarked'],
#       dtype='object')
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Full_name, Sex, Age, SibSp, Parch, Ticket, Fare, Class, Embarked]
# Index: []

# %%
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Full_name     Name.1  \
# 0                            Braund, Mr. Owen Harris     Braund
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings
# 2                             Heikkinen, Miss. Laina  Heikkinen
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle
# 4                           Allen, Mr. William Henry      Allen
# 5                                   Moran, Mr. James      Moran
#
#                                       Surname     Sex   Age  SibSp  Parch  \
# 0                             Mr. Owen Harris    male  22.0      1      0
# 1  Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                 Miss. Laina  female  26.0      0      0
# 3          Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                           Mr. William Henry    male  35.0      0      0
# 5                                   Mr. James    male   NaN      0      0
#
#              Ticket     Fare Class Embarked  Unnamed: 14 Unnamed: 15  \
# 0         A/5 21171   7.2500   NaN        S          NaN         NaN
# 1          PC 17599  71.2833   C85        C          NaN         NaN
# 2  STON/O2. 3101282   7.9250   NaN        S          NaN         NaN
# 3            113803  53.1000  C123        S          NaN         NaN
# 4            373450   8.0500   NaN        S          NaN      Monday
# 5            330877   8.4583   NaN        Q          NaN         NaN
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN     Tuesday   Wednesday    Thursday      Friday
# 5          NaN         NaN         NaN         NaN         NaN
